# %%
#toy model ODE

# %%
from scipy.integrate import solve_ivp
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
def fun(t, y):
    return np.array([ -1*y[0]*y[1] + 2000*y[0]*y[2] ,
                     -2*y[1]*y[2],
                     -2000*y[2]*y[0]
                    ])
    #return np.array([-1, -2, -100]) * y

# %%
res = solve_ivp(fun, (0, 10), np.array([1, 1, 1]), method = 'Radau')

# %%
res
# Out:
#   message: 'The solver successfully reached the end of the integration interval.'
#      nfev: 419
#      njev: 15
#       nlu: 72
#       sol: None
#    status: 0
#   success: True
#         t: array([0.00000000e+00, 1.93772887e-04, 4.11936197e-04, 4.68058299e-04,
#        6.95453998e-04, 8.16312328e-04, 9.37170657e-04, 1.05802899e-03,
#        1.24372959e-03, 1.42943019e-03, 1.60843870e-03, 1.78744720e-03,
#        1.96645571e-03, 2.18194355e-03, 2.39743140e-03, 2.67536831e-03,
#        3.02296084e-03, 3.49526529e-03, 4.21694138e-03, 5.56150116e-03,
#        9.27505832e-03, 2.82868016e-02, 1.97464971e-01, 5.91304281e-01,
#        1.29724819e+00, 2.00319209e+00, 2.43544761e+00, 2.97316369e+00,
#        3.57644570e+00, 4.31962661e+00, 4.69121707e+00, 4.84148744e+00,
#        4.99175781e+00, 5.61616896e+00, 6.24255275e+00, 7.01490836e+00,
#        7.78726397e+00, 8.55961957e+00, 9.49751203e+00, 1.00000000e+01])
#  t_events: None
#         y: array([[ 1.00000000e+00,  1.36898503e+00,  1.67653535e+00,
#          1.73269247e+00,  1.88220782e+00,  1.92505206e+00,
#          1.95238245e+00,  1.96954504e+00,  1.98410057e+00,
#          1.99091411e+00,  1.99391106e+00,  1.99519852e+00,
#          1.99564688e+00,  1.99566255e+00,  1.99542130e+00,
#          1.99495979e+00,  1.99430116e+00,  1.99336978e+00,
#          1.99193436e+00,  1.98925985e+00,  1.98189142e+00,
#          1.94459375e+00,  1.64212672e+00,  1.10785581e+00,
#          5.47161633e-01,  2.70237978e-01,  1.75448740e-01,
#          1.02514671e-01,  5.61007306e-02,  2.66973053e-02,
#          1.84150974e-02,  1.58471350e-02,  1.36374618e-02,
#          7.30708975e-03,  3.90748546e-03,  1.80588722e-03,
#          8.34746518e-04,  3.86831460e-04,  1.51342946e-04,
#          9.15234820e-05],
#        [ 1.00000000e+00,  9.99685785e-01,  9.99482994e-01,
#          9.99450009e-01,  9.99367061e-01,  9.99344447e-01,
#          9.99330239e-01,  9.99321372e-01,  9.99313829e-01,
#          9.99310218e-01,  9.99308536e-01,  9.99307712e-01,
#          9.99307309e-01,  9.99307086e-01,  9.99306992e-01,
#          9.99306945e-01,  9.99306928e-01,  9.99306923e-01,
#          9.99306922e-01,  9.99306922e-01,  9.99306922e-01,
#          9.99306922e-01,  9.99306924e-01,  9.99306950e-01,
#          9.99307487e-01,  9.99307520e-01,  9.99307515e-01,
#          9.99307504e-01,  9.99307500e-01,  9.99308266e-01,
#          9.99308350e-01,  9.99308364e-01,  9.99308361e-01,
#          9.99308353e-01,  9.99308328e-01,  9.99308213e-01,
#          9.99308039e-01,  9.99308578e-01,  9.99310395e-01,
#          9.99311208e-01],
#        [ 1.00000000e+00,  6.30784617e-01,  3.22899639e-01,
#          2.66646863e-01,  1.16718661e-01,  7.36443111e-02,
#          4.60796447e-02,  2.86801332e-02,  1.37575922e-02,
#          6.57513586e-03,  3.22174576e-03,  1.57746744e-03,
#          7.72151139e-04,  3.26731287e-04,  1.38262256e-04,
#          4.56178509e-05,  1.14101961e-05,  1.74433107e-06,
#          1.05171320e-07,  2.74207276e-09,  1.66074384e-10,
#         -8.92117585e-10, -2.28190308e-08, -1.59650587e-07,
#         -1.19193925e-06, -1.25318201e-07,  4.49749754e-08,
#          6.94717898e-08, -1.90692764e-08, -1.91152525e-06,
#         -2.68304055e-07,  1.15832312e-08,  3.50362272e-08,
#          4.89441485e-08,  6.79839571e-08,  1.60786651e-07,
#          3.60107053e-08, -1.24036765e-06, -8.63873355e-07,
#         -7.66642022e-07]])
#  y_events: None

# %%
res.t
res.y[:, -1]
# Out:
# array([ 9.15234820e-05,  9.99311208e-01, -7.66642022e-07])

# %%
plt.figure()
plt.plot(res.t, res.y[0], label= '0')
plt.plot(res.t, res.y[1], label= '1')
plt.plot(res.t, res.y[2], label= '2')
plt.yscale('log')
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
1/np.exp(3)
# Out:
# 0.049787068367863944
